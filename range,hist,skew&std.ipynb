# %%
import pandas as pd
df=pd.read_excel("C:\\resources\\resources\\mean median mode.xlsx")
df['salary_2018'].max()-df['salary_2018'].min()
# Out:
# 281883.48

# %%
import pandas as pd
df=pd.read_excel("C:\\resources\\resources\\mean median mode.xlsx")
df['salary_2018'].hist()
# Out:
# <Axes: >

# %%
import pandas as pd
df=pd.read_excel("C:\\resources\\resources\\Skewness.xlsx")
df['manager_sat'].plot.hist()
df['manager_sat'].skew()
# Out:
# 1.2416158547092389

# %%
df['employee_sat'].plot.hist()
df['employee_sat'].skew()
# Out:
# 1.1886925569711662

# %%
df['percent_salary_hike'].plot.hist()
df['percent_salary_hike'].skew()
# Out:
# -3.412260009017281

# %%
import pandas as pd
df=pd.read_excel("C:\\resources\\resources\\mean median mode.xlsx")
from sklearn import preprocessing
std_df=preprocessing.scale(df["salary_2018"])
std_df
# Out:
# array([-0.15416035, -0.21735705, -0.93850791, ..., -0.02158076,
#        -0.24787267, -0.47163915])

# %%
import pandas as pd
df=pd.read_excel("C:\\resources\\resources\\mean median mode.xlsx")
df['department'].value_counts()
# Out:
# department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
import pandas as pd
df=pd.read_excel("C:\\resources\\resources\\mean median mode.xlsx")
df['department'].value_counts(normalize=True)
# Out:
# department
# Research & Development    0.653741
# Sales                     0.303401
# Human Resources           0.042857
# Name: proportion, dtype: float64

# %%
import pandas as pd
df=pd.read_excel("C:\\resources\\resources\\mean median mode.xlsx")
df['department'].value_counts(normalize=True)*100
# Out:
# department
# Research & Development    65.374150
# Sales                     30.340136
# Human Resources            4.285714
# Name: proportion, dtype: float64
